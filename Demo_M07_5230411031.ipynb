# %% [markdown]
# # Stack & Queue

# %% [markdown]
# # Stack

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self, value):
        new_node = Node(value)
        self.top = new_node
        self.height = 1

my_stack = Stack(4)
print('Top:', my_stack.top.value)
print('Height:', my_stack.height)
# Out:
# Top: 4
# Height: 1

# %% [markdown]
# Skenario 1 : Push

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

class Stack:
  def __init__(self, value):
    new_node = Node(value)
    self.top = new_node
    self.height = 1

  def print_stack(self):
    temp = self.top
    while temp is not None:
      print(temp.value)
      temp = temp.next

  def push(self, value):
    new_node = Node(value)
    if self.height == 0:
      self.top = new_node
    else:
      new_node.next = self.top
      self.top = new_node
    self.height += 1

my_stack = Stack(2)
print('Stack before push(1):')
my_stack.print_stack()

my_stack.push(1)

print('\nStack after push(1):')
my_stack.print_stack()
# Out:
# Stack before push(1):
# 2
#
# Stack after push(1):
# 1
# 2

# %% [markdown]
# Skenario 2 : Pop

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

class Stack:
  def __init__(self, value):
    new_node = Node(value)
    self.top = new_node
    self.height = 1

  def print_stack(self):
    temp = self.top
    while temp is not None:
      print(temp.value)
      temp = temp.next

  def push(self, value):
    new_node = Node(value)
    if self.height == 0:
      self.top = new_node
    else:
      new_node.next = self.top
      self.top = new_node
    self.height += 1

  def pop(self):
    if self.height == 0:
      return None
    temp = self.top
    self.top = self.top.next
    self.height -= 1
    return temp.value

my_stack = Stack(4)
my_stack.push(3)
my_stack.push(2)
my_stack.push(1)

print('Stack before pop():')
my_stack.print_stack()

print('\nPoppped node:')
print(my_stack.pop())

print('\nStack after pop():')
my_stack.print_stack()
# Out:
# Stack before pop():
# 1
# 2
# 3
# 4
#
# Poppped node:
# 1
#
# Stack after pop():
# 2
# 3
# 4

# %% [markdown]
# # Queue

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

class Queue:
  def __init__(self, value):
    new_node = Node(value)
    self.first = new_node
    self.last = new_node
    self.length = 1

  def print_queue(self):
    temp = self.first
    while temp is not None:
      print(temp.value)
      temp = temp.next

my_queue = Queue(4)
my_queue.print_queue()
# Out:
# 4

# %% [markdown]
# Scenario 1 : Enqueue

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

class Queue:
  def __init__(self, value):
    new_node = Node(value)
    self.first = new_node
    self.last = new_node
    self.length = 1

  def print_queue(self):
    temp = self.first
    while temp is not None:
      print(temp.value)
      temp = temp.next

  def enqueue(self, value):
    new_node = Node(value)
    if self.first is None:
      self.first = new_node
      self.last = new_node
    else:
      self.last.next = new_node
      self.last = new_node
    self.length += 1

my_queue = Queue(1)
print('Queue before enqueue(2):')
my_queue.print_queue()

my_queue.enqueue(2)

print('\nQueue after enqueue(2):')
my_queue.print_queue()
# Out:
# Queue before enqueue(2):
# 1
#
# Queue after enqueue(2):
# 1
# 2

# %% [markdown]
# Skenario 2 : Dequeue

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

class Queue:
  def __init__(self, value):
    new_node = Node(value)
    self.first = new_node
    self.last = new_node
    self.length = 1

  def print_queue(self):
    temp = self.first
    while temp is not None:
      print(temp.value)
      temp = temp.next

  def enqueue(self, value):
    new_node = Node(value)
    if self.first is None:
      self.first = new_node
      self.last = new_node
    else:
      self.last.next = new_node
      self.last = new_node
    self.length += 1

  def dequeue(self):
    if self.length == 0:
      return None
    temp = self.first
    if self.length == 1:
      self.first = None
      self.last = None
    else:
      self.first = self.first.next
    self.length -= 1
    return temp.value

my_queue = Queue(1)
my_queue.enqueue(2)

print(my_queue.dequeue())
print(my_queue.dequeue())
print(my_queue.dequeue())
# Out:
# 1
# 2
# None

# %% [markdown]
# # 8.4 Latihan

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self, value):
        new_node = Node(value)
        self.top = new_node
        self.bottom = new_node
        self.height = 1

    def print_stack(self):
        temp = self.top
        while temp is not None:
            print(temp.value)
            temp = temp.next

    def insert_at_bottom(self, value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
            self.bottom = new_node
        else:
            self.bottom.next = new_node
            self.bottom = new_node
        self.height += 1

    def push(self, value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
            self.bottom = new_node
        else:
            new_node.next = self.top
            self.top = new_node
        self.height += 1

    def wadah(self, value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
            self.bottom = new_node
        else:
            new_node.next = self.top
            self.top = new_node

    def insert_at_bottom(self, value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
            self.bottom = new_node
        else:
            self.bottom.next = new_node
            self.bottom = new_node
        self.height += 1

    def pop(self):
        if self.height == 0:
            return None
        temp = self.top
        self.top = self.top.next
        self.height -= 1
        return temp.value

    

my_stack = Stack(4)
my_stack.push(3)
my_stack.push(2)
my_stack.push(1)

print('Stack sebelum sisip_stack(5, 1):')
my_stack.print_stack()

my_stack.insert_at_bottom(5)

print('\nStack after sisip_stack(5, 1):')
my_stack.print_stack()
# Out:
# Stack sebelum sisip_stack(5, 1):
# 1
# 2
# 3
# 4
#
# Stack after sisip_stack(5, 1):
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Tugas

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self, value):
        new_node = Node(value)
        self.top = new_node
        self.height = 1

    def print_stack(self):
        temp = self.top
        while temp is not None:
            print(temp.value)
            temp = temp.next

    def push(self, value):
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
        else:
            new_node.next = self.top
            self.top = new_node
        self.height += 1

    def pop(self):
        if self.height == 0:
            return None
        temp = self.top
        self.top = self.top.next
        self.height -= 1
        return temp.value

    def sisip_stack():
        
        
       

my_stack = Stack(4)
my_stack.push(3)
my_stack.push(2)
my_stack.push(1)

print('Stack sebelum sisip_stack(5, 1):')
my_stack.print_stack()

my_stack.sisip_stack(5, 1)

print('\nStack after sisip_stack(5, 1):')
my_stack.print_stack()

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Queue:
    def __init__(self):
        self.first = None
        self.last = None
        self.length = 0

    def print_queue(self):
        temp = self.first
        while temp is not None:
            print(temp.value)
            temp = temp.next

    def enqueue(self, value):
        if not isinstance(value, int):
            print("Invalid value")
            return
        new_node = Node(value)
        if self.first is None:
            self.first = new_node
            self.last = new_node
        else:
            self.last.next = new_node
            self.last = new_node
        self.length += 1

    def dequeue(self):
        if self.length == 0:
            return None
        temp = self.first
        if self.length == 1:
            self.first = None
            self.last = None
        else:
            self.first = self.first.next
        self.length -= 1
        return temp.value

    def desperation(self, x):
        if x < 0 or x >= self.length:
            print("Invalid index")
            return

        if x == 0:
            temp = self.first
            self.first = self.first.next
            if self.length == 1:
                self.last = None
            self.length -= 1
            print("Nilai yang anda hapus adalah", temp.value)
            return temp.value

        temp = self.first
        for _ in range(x - 1):
            temp = temp.next

        if  temp.next:
            node_to_remove = temp.next
            temp.next = node_to_remove.next
            self.length -= 1
            if x == self.length - 1:
                self.last = temp
            print("Nilai yang anda hapus adalah", node_to_remove.value)
            return node_to_remove.value
        else:
            print("Invalid index")
            return

while True:
    print("\nMenu")
    print("1. Make Queue")
    print("2. Enqueue")
    print("3. Print Queue")
    print("4. Remove at Index")
    print("5. Exit")
    pilihan = int(input("\nMasukkan pilihan: "))
    if pilihan == 1:
        value = int(input("\nMasukkan nilai pertama: "))
        my_queue = Queue()
        my_queue.enqueue(value)
    elif pilihan == 2:
        while True:
            try:
                value = int(input("\nMasukkan nilai (Masukkan 0 untuk berhenti input): "))
                if value == 0:
                    break
                else:
                    my_queue.enqueue(value)
            except:
                if not my_queue:
                    print("\nSepertinya anda belum membuat queue, silahkan buat queue terlebih dahulu")
                break
    elif pilihan == 3:
        my_queue.print_queue()
    elif pilihan == 4:
        x = int(input("\nMasukkan index: "))
        my_queue.desperation(x)
    elif pilihan == 5:
        break
    else:
        print("\nPilihan tidak valid")
# Out:
# Menu
# 1. Make Queue
# 2. Enqueue
# 3. Print Queue
# 4. Desperation
# 5. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 66
#      64 pilihan = int(input("\nMasukkan pilihan: "))
#      65 if pilihan == 1:
# ---> 66     value = int(input("\nMasukkan nilai pertama: "))
#      67     my_queue = Queue(value)
#      68 elif pilihan == 2:
#
# ValueError: invalid literal for int() with base 10: ''
